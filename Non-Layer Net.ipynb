# %%
from chromosome import *
import pandas as pd 
import numpy as np

# %%
C = Chromosome(0, inputs=2, outputs=3, hidden=4)
C.visualize()
# Out:
# <Axes: >

# %%
C.NN.run([0.1, 0.2])
# Out:
# array([0.0, 0.8441116520825054, 1.0602173783265316], dtype=object)
