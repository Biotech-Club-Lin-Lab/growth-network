# %%
from chromosome import * 
from NN import *

# %%
C = Chromosome(0, inputs=3, outputs=4, hidden=5)
C.show()

C_NN = NN(C)
X = np.array([0,1,2])
print('input layer: ',X)
out = C_NN.result(X, verbose=True)
print("output layer: ", out)
# Out:
# input layer:  [0 1 2]
# layer 1:  [0.87948844 0.         0.18724474 2.96629729 0.        ]
# layer 2:  [0.1055899  1.24920697 0.         0.        ]
# output layer:  [0.1055899  1.24920697 0.         0.        ]

# %%
nodes, edges = get_dfs(C)
display(nodes, edges)
# Out:
#     id   layer  layer id      bias
# 0    0   input         0 -0.008930
# 1    1   input         1  0.981969
# 2    2   input         2  0.695087
# 3    3       1         0  0.524671
# 4    4       1         1 -0.292884
# 5    5       1         2 -0.216501
# 6    6       1         3  0.912078
# 7    7       1         4  0.944909
# 8    8  output         0 -0.020236
# 9    9  output         1  0.697496
# 10  10  output         2 -0.676906
# 11  11  output         3 -0.551865
#     id  source  target    weight  enabled
# 0    0       0       5 -0.907707     True
# 1    1       0       3  0.230761     True
# 2    2       0       4 -0.682542     True
# 3    3       1       7 -0.874808     True
# 4    4       1       3  0.354818     True
# 5    5       1       6  0.525535     True
# 6    6       1       4 -0.867575     True
# 7    7       1       5  0.403746     True
# 8    8       2       6  0.764342     True
# 9    9       2       7 -0.542345     True
# ...
